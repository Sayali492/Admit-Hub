# %%
import pandas as pd
df1=pd.read_csv("Segregated_data_1-10.csv")
df2=pd.read_csv("Segregated_data_200-300.csv")
df3=pd.read_csv("Segregated_data_400-600.csv")
df4=pd.read_csv("Segregated_data_300-400.csv")
df5=pd.read_csv("Segregated_data_11-200.csv")
df=pd.concat([df1,df2,df3,df4,df5])

# %%
df
# Out:
#       Unnamed: 0                                         University    result  \
# 0            1.0  Aerospace Engineering, University Of Texas At ...  Accepted
# 1           26.0  Electrical And Computer Engineering, Universit...  Accepted
# 2           34.0  Marketing, University Of Texas At Austin  Quan...  Accepted
# 3           74.0  Special Education, University Of Texas At Aust...  Accepted
# 4           77.0  Speech Language Pathology, University Of Texas...  Accepted
# ...          ...                                                ...       ...
# 6470    259779.0  American Culture Studies, Bowling Green State ...  Accepted
# 6471    259780.0  American Culture Studies, Bowling Green State ...  Accepted
# 6472    259998.0  Music Education, Bowling Green State Universit...  Accepted
# 6473    260028.0  Speech - Language Pathology, Bowling Green Sta...  Accepted
# 6474    260045.0  Mathematics And Statistics, Bowling Green Stat...  Accepted
#
# ...

# %%
df.drop_duplicates()
# Out:
#       Unnamed: 0                                         University    result  \
# 0            1.0  Aerospace Engineering, University Of Texas At ...  Accepted
# 1           26.0  Electrical And Computer Engineering, Universit...  Accepted
# 2           34.0  Marketing, University Of Texas At Austin  Quan...  Accepted
# 3           74.0  Special Education, University Of Texas At Aust...  Accepted
# 4           77.0  Speech Language Pathology, University Of Texas...  Accepted
# ...          ...                                                ...       ...
# 6470    259779.0  American Culture Studies, Bowling Green State ...  Accepted
# 6471    259780.0  American Culture Studies, Bowling Green State ...  Accepted
# 6472    259998.0  Music Education, Bowling Green State Universit...  Accepted
# 6473    260028.0  Speech - Language Pathology, Bowling Green Sta...  Accepted
# 6474    260045.0  Mathematics And Statistics, Bowling Green Stat...  Accepted
#
# ...

# %%
df.to_csv("Segregated_data-final.csv")
